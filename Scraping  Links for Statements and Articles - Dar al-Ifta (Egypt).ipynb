# %%
#We have to use selenium because the page and all the info we need to scrape loads dynamically. 
#The dynamism is also why we need to tell our browser to 

from selenium import webdriver 
import time 


#Opens up a chrome browser and navigate to webpage 

 

#I have to tell my code where to find chromedriver so I can use it, most poeple 
driver = webdriver.Chrome(r"C:/Users/twint/Downloads/chromedriver_win32/chromedriver.exe")

driver.get('https://www.dar-alifta.org/ar/Statement.aspx?sec=media&catID=16')

           

print(driver.current_url)



#We need the code to click through all the pages and gather all of the 


#This bit of code gives use the positions of all the links for any page so that the crawlers knows where to go. 


link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')

link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 

link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')

link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')

link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')

link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')

link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')

page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]

#Theses are the buttons on the page, each is only separated by one number, but its sensitive, so I include everything. 
page_2 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[2]/a'
page_3 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[3]/a'
page_4 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[4]/a'
page_5 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[5]/a'
page_6 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[6]/a'
page_7 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[7]/a'
page_8 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[8]/a'
page_9 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[9]/a'
page_10 ='//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[10]/a'
page_11 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[11]/a'


#The buttons for the first ten pages are arranged a little differently because we start with button 2 instead of 4 for all others. 
#It has to do with how the website is arranged. 
first_10_pages = [page_2, page_3, page_4, page_5, page_6, page_7, page_8, page_9, page_10, page_11]




master_link_list = []

#We need to get the links from the first page

for article in page_link_list: 
    link = article.get_attribute('href')
    master_link_list.append(link)
    




#Then we need this code to run for the 11 pages 
for page in first_10_pages:
    button=driver.find_element_by_xpath(page)
    button.click()
    time.sleep(20)
    link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')
    link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 
    link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')
    link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')
    link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')
    link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')
    link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')
    page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]
    for article in page_link_list: 
        link = article.get_attribute('href')
        print(link)
        master_link_list.append(link)
        
        
        
        

#The problem that we have is that we have an irregular stoppoing point for the pages that we scroll through. So I am 
#going to create an arbitary range.



page_12 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[4]/a'
page_13 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[5]/a'
page_14 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[6]/a'
page_15 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[7]/a'
page_16 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[8]/a'
page_17 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[9]/a'
page_18 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[10]/a'
page_19 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[11]/a'
page_20 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[12]/a'
page_21 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[13]/a'


last_page = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[12]/a'


pages = [page_12, page_13, page_14, page_15, page_16, page_17, page_18, page_19, page_20, page_21]

news_range = range(1,21)





for x in news_range: 
    for page in pages:
        
        button=driver.find_element_by_xpath(page)
        button.click()
        time.sleep(20)
        link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')
        link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 
        link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')
        link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')
        link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')
        link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')
        link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr
unscraped = [unscrap_1, unscrap_2, unscrap_3, unscrap_4, unscrap_5, unscrap_6, unscrap_7, unscrap_8, unscrap_9, unscrap_10, 
            unscrap_11, unscrap_12, unscrap_13, unscrap_14]





for thing in unscraped: 
    master_link_list.append(thing)

# %%
#We save the scraped links in a csv. 

results = open('dar_statements_2.csv', 'w')

for link in master_link_list:
    results.write(link + '\n')
    
results.close()

# %%
#This is the same basic code as above, but it scrapes the articles. 


#We have to use selenium because the page and all the info we need to scrape loads dynamically. 


from selenium import webdriver 
import time 


#Open up a chrome browser and navigate to webpage 

 

#Due to so some horeshsit I have to tell my code where to find chromedriver so I can use it. 
driver = webdriver.Chrome(r"C:/Users/twint/Downloads/chromedriver_win32/chromedriver.exe")

driver.get('https://www.dar-alifta.org/ar/Statement.aspx?sec=media&catID=14')

           

print(driver.current_url)


#We need the code to click through all the pages and gather all of the 


#This bit of code gives use the positions of all the links for any page so that the crawlers knows where to go. 


link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')

link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 

link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')

link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')

link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')

link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')

link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')

page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]

#Theses are the buttons on the page, each is only separated by one number, but its sensitive as fuck, so I include everything. 
page_2 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[2]/a'
page_3 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[3]/a'
page_4 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[4]/a'
page_5 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[5]/a'
page_6 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[6]/a'
page_7 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[7]/a'
page_8 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[8]/a'
page_9 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[9]/a'
page_10 ='//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[10]/a'
page_11 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[11]/a'


#The buttons for the first ten pages are arranged a little differently because we start with button 2 instead of 4 for all others. 
#It has to do with how the website is arranged. 
first_10_pages = [page_2, page_3, page_4, page_5, page_6, page_7, page_8, page_9, page_10, page_11]

time.sleep(5)



article_link_list = []

#We need to get the links from the first page

for article in page_link_list: 
    link = article.get_attribute('href')
    article_link_list.append(link)
    


for page in first_10_pages:
    button=driver.find_element_by_xpath(page)
    button.click()
    time.sleep(8)
    #time.sleep(20)
    link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')
    link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 
    link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')
    link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')
    link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')
    link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')
    link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')
    page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]
    for article in page_link_list: 
        link = article.get_attribute('href')
        #print(link)
        article_link_list.append(link)
        
        

#The problem that we have is that we have an irregular stoppoing point for the pages that we scroll through. So I am 
#going to create an arbitary range. I am certain there is a more elegant solution, but we ain't got time for that. 



page_12 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[4]/a'
page_13 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[5]/a'
page_14 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[6]/a'
page_15 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[7]/a'
page_16 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[8]/a'
page_17 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[9]/a'
page_18 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[10]/a'
page_19 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[11]/a'
page_20 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[12]/a'
page_21 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[13]/a'





pages = [page_12, page_13, page_14, page_15, page_16, page_17, page_18, page_19, page_20, page_21]


revolutions = range(1,10)





for revolution in revolutions: 
    for page in pages: 
        button=driver.find_element_by_xpath(page)
        button.click()
        time.sleep(8)
        #time.sleep(20)
        link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')
        link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 
        link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')
        link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')
        link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')
        link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')
        link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')
        page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]
        for article in page_link_list:
            link = article.get_attribute('href')
            article_link_list.append(link)

        
#Let's see if this code works and where we end up. Then we'll manually add the remaining pages and add the code to scrape the links. 


#It worked but we still need to click on 102, 103, and 104


page_102 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[10]/a'
page_103 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[11]/a'
page_104 = '//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[8]/td/table/tbody/tr/td[12]/a'

stragglers = [page_102, page_103]


for page in stragglers:
    button = driver.find_element_by_xpath(page)
    button.click()
    time.sleep(5)
    #time.sleep(20)
    link_1 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[1]/td/div[1]/div[2]/a')
    link_2 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[2]/td/div[1]/div[2]/a') 
    link_3 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[3]/td/div[1]/div[2]/a')
    link_4 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[4]/td/div[1]/div[2]/a')
    link_5 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[5]/td/div[1]/div[2]/a')
    link_6 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[6]/td/div[1]/div[2]/a')
    link_7 = driver.find_element_by_xpath('//*[@id="ctl00_ContentPlaceHolder1_Grid"]/tbody/tr[7]/td/div[1]/div[2]/a')
    page_link_list= [link_1, link_2, link_3, link_4, link_5, link_6, link_7]
    for article in page_link_list:
        link = article.get_attribute('href')
        article_link_list.append(link)
    
    
button = driver.find_element_by_xpath(page_104)
button.click()


    
#I can get my crawler to get to the final page but it just gives me the link to page 103. Strange. 
    
final_1 = 'https://www.dar-alifta.org/ar/Viewstatement.aspx?sec=media&ID=2858&_%D9%85%D8%B1%D8%B5%D8%AF_%D8%A7%D9%84%D8%A5%D9%81%D8%AA%D8%A7%D8%A1_%D9%84%D9%84%D8%A5%D8%B3%D9%84%D8%A7%D9%85%D9%88%D9%81%D9%88%D8%A8%D9%8A%D8%A7_%D9%8A%D8%B1%D8%AD%D8%A8_%D8%A8%D9%85%D9%88%D9%82%D8%B9_%D8%A3%D9%84%D9%85%D8%A7%D9%86%D9%8A_%D9%8A%D9%84%D8%A7%D8%AD%D9%82_%D8%A7%D9%84%D8%B4%D8%A7%D8%A6%D8%B9%D8%A7%D8%AA_%D8%AD%D9%88%D9%84_%D8%A7%D9%84%D9%84%D8%A7%D8%AC%D8%A6%D9%8A%D9%86'
final_2 = 'https://www.dar-alifta.org/ar/Viewstatement.aspx?sec=media&ID=2857&%D9%85%D8%B1%D8%B5%D8%AF_%D8%A7%D9%84%D8%A5%D9%81%D8%AA%D8%A7%D8%A1_%D9%84%D9%84%D8%A5%D8%B3%D9%84%D8%A7%D9%85%D9%88%D9%81%D9%88%D8%A8%D9%8A%D8%A7_%D9%8A%D8%AF%D9%8A%D9%86_%D8%A5%D8%BA%D9%84%D8%A7%D9%82_%D8%AC%D8%A7%D9%85%D8%B9%D8%A9_%D8%A3%D9%84%D9